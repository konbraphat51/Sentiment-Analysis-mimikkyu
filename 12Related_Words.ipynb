# %% [markdown]
# # 11で出した重要語と共起する単語を算出

# %%
ID = "mimikkyu"

POPULATION_ID = "pokemon"

#10の途中経過
without_stopwords_text_file = "Progresses/NonStopword/%s-from-%s.txt"%(ID, POPULATION_ID)

#10の結果
sentiment_file = "Sentiment/%s-from-%s.txt"%(ID, POPULATION_ID)

##TFIDFモデル
tfidf_model_file = "Models/Tfidf/%s-from-%s.model"%(ID, POPULATION_ID)

#内部的に品詞を区別する区切り文字
TOKEN_DIVIDER = "<334>"

# %%
#ここだけのストップワード
#投稿そのものを除外するのではなく、関連単語から除外する
local_stopwords = ["ミミッキュ", "br", "ミミ"]

# %% [markdown]
# ## 読み込み

# %%
import pandas as pd
import seaborn as sns

# %%
df_main = pd.read_table(without_stopwords_text_file)

#本ノートでは生テキストではなく形態素解析後のテキストが渡される
def tokenize(text):
    return text.split(TOKEN_DIVIDER)

df_main.head(2)
# Out:
#                   date  link_index  number                      content  \
# 0  2017/01/10|18/43/00       57557       4   いちおつまり  やっとミミッキュ理想でた <\br>
# 1  2017/01/10|19/04/00       57557      78           ミミッキュて生き残るの？ <\br>
#
#                                     disassembled_all  \
# 0  *<334>一<334>おー<334>詰まり<334>漸と<334>ミミッキュ<334>理想...
# 1  *<334>ミミ<334>っ<334>きゅっ<334>って<334>生き残る<334>の<3...
#
#          disassembled_target Sentiment
# 0  一<334>ミミッキュ<334>理想<334>br       pos
# 1                  ミミ<334>br       neg

# %%
df_sentiment = pd.read_table(sentiment_file)

df_sentiment.head(2)
# Out:
#    Token     TFIDF  Sentiment  Counts
# 0     br  0.187560   0.149914   25468
# 1  ミミッキュ  0.046337  -0.172684    4598

# %% [markdown]
# ## 単純な共起回数

# %% [markdown]
# ### 単語ベクトルの用意

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# %%
vectorizer = CountVectorizer(tokenizer=tokenize, stop_words=local_stopwords, ngram_range=(1,1), min_df=20)
vectorizer = vectorizer.fit(df_main["disassembled_target"])
# Out:
# c:\Users\brigh\anaconda3\envs\jpnlp\lib\site-packages\sklearn\feature_extraction\text.py:516: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
#keywordに共起する回数の多いものを数える
def get_freq(keyword):
    #keywordを含む行を走査
    df_keyword = np.empty((0, df_main.shape[1]))
    for _, row in df_main.iterrows():
        if keyword in tokenize(row["disassembled_all"]):
            df_keyword = np.vstack([df_keyword, row.values])

    #pandas行列に
    df_keyword = pd.DataFrame(df_keyword, columns=df_main.columns)

    #単語ベクトルの回数数える
    freq_spycy = vectorizer.transform(df_keyword["disassembled_target"])
    freq_df = pd.DataFrame(freq_spycy.toarray(), columns=vectorizer.get_feature_names_out())
    freq_sum = freq_df.sum(axis=0)
    
    #単語名と結び付け
    freq_sum = freq_sum.sort_values(ascending=False)

    return freq_sum

get_freq("良い").head(5)
# Out:
# 良い    2308
# 無い     326
# v      222
# 夢      194
# 方      190
# dtype: int64

# %%
df_sentiment["CoOccurre-FREQ"] = ""
for index, row in df_sentiment.iterrows():
    freq = get_freq(row["Token"])
    end = 6
    if len(freq) <= 1:
        end = 1
    elif len(freq) < 6:
        end = len(freq)

    if end != 1:
        cooc = ", ".join(list(freq.iloc[1:end].index))
        df_sentiment.at[index, "CoOccurre-FREQ"] = cooc

pd.set_option('display.max_rows', 100)
df_sentiment.head(100).style.background_gradient(cmap="vlag_r", axis=0, subset="Sentiment")
# Out:
# <style type="text/css">
# #T_8ede7_row0_col2, #T_8ede7_row38_col2 {
#   background-color: #f1eff2;
#   color: #000000;
# }
# #T_8ede7_row1_col2 {
#   background-color: #dfb4b2;
#   color: #000000;
# }
# #T_8ede7_row2_col2 {
#   background-color: #d7a29f;
#   color: #000000;
# }
# #T_8ede7_row3_col2 {
#   background-color: #f5f2f4;
#   color: #000000;
# }
# #T_8ede7_row4_col2 {
#   background-color: #ba5d5c;
#   color: #f1f1f1;
# }
# #T_8ede7_row5_col2 {
#   background-color: #839dc4;
#   color: #f1f1f1;
# }
# #T_8ede7_row6_col2 {
#   background-color: #3470bc;
#   color: #f1f1f1;
# }
# #T_8ede7_row7_col2, #T_8ede7_row77_col2 {
#   background-color: #efeef1;
#   color: #000000;
# }
# #T_8ede7_row8_col2 {
#   background-color: #c0c9d9;
#   color: #000000;
# }
# #T_8ede7_row9_col2, #T_8ede7_row56_col2, #T_8ede7_row73_col2 {
#   background-color: #eeedf0;
#   color: #000000;
# }
# #T_8ede7_row10_col2 {
#   background-color: #e2e3ea;
#   color: #000000;
# }
# #T_8ede7_row11_col2 {
#   background-color: #f0dbda;
#   color: #000000;
# }
# #T_8ede7_row12_col2 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_8ede7_row13_col2 {
#   background-color: #d2d7e1;
#   color: #000000;
# }
# #T_8ede7_row14_col2, #T_8ede7_row15_col2, #T_8ede7_row66_col2, #T_8ede7_row94_col2 {
#   background-color: #dde0e7;
#   color: #000000;
# }
# #T_8ede7_row16_col2, #T_8ede7_row34_col2, #T_8ede7_row54_col2, #T_8ede7_row80_col2 {
#   background-color: #f4e3e2;
#   color: #000000;
# }
# #T_8ede7_row17_col2, #T_8ede7_row45_col2 {
#   background-color: #eed7d5;
#   color: #000000;
# }
# #T_8ede7_row18_col2, #T_8ede7_row49_col2 {
#   background-color: #c7cedc;
#   color: #000000;
# }
# #T_8ede7_row19_col2 {
#   background-color: #eacdcb;
#   color: #000000;
# }
# #T_8ede7_row20_col2 {
#   background-color: #d9a5a2;
#   color: #000000;
# }
# #T_8ede7_row21_col2, #T_8ede7_row57_col2 {
#   background-color: #d59c99;
#   color: #f1f1f1;
# }
# #T_8ede7_row22_col2 {
#   background-color: #c47371;
#   color: #f1f1f1;
# }
# #T_8ede7_row23_col2, #T_8ede7_row64_col2 {
#   background-color: #3f75bc;
#   color: #f1f1f1;
# }
# #T_8ede7_row24_col2, #T_8ede7_row44_col2, #T_8ede7_row75_col2 {
#   background-color: #e6c5c3;
#   color: #000000;
# }
# #T_8ede7_row25_col2 {
#   background-color: #bdc6d7;
#   color: #000000;
# }
# #T_8ede7_row26_col2, #T_8ede7_row32_col2 {
#   background-color: #c67875;
#   color: #f1f1f1;
# }
# #T_8ede7_row27_col2 {
#   background-color: #d39794;
#   color: #f1f1f1;
# }
# #T_8ede7_row28_col2 {
#   background-color: #e3bfbd;
#   color: #000000;
# }
# #T_8ede7_row29_col2 {
#   background-color: #adbbd1;
#   color: #000000;
# }
# #T_8ede7_row30_col2 {
#   background-color: #faf2f1;
#   color: #000000;
# }
# #T_8ede7_row31_col2 {
#   background-color: #e8cac8;
#   color: #000000;
# }
# #T_8ede7_row33_col2 {
#   background-color: #9fb0cc;
#   color: #000000;
# }
# #T_8ede7_row35_col2 {
#   background-color: #abb9d0;
#   color: #000000;
# }
# #T_8ede7_row36_col2, #T_8ede7_row81_col2 {
#   background-color: #dcdee6;
#   color: #000000;
# }
# #T_8ede7_row37_col2 {
#   background-color: #d29593;
#   color: #f1f1f1;
# }
# #T_8ede7_row39_col2 {
#   background-color: #d8a3a0;
#   color: #000000;
# }
# #T_8ede7_row40_col2 {
#   background-color: #f8f4f5;
#   color: #000000;
# }
# #T_8ede7_row41_col2, #T_8ede7_row99_col2 {
#   background-color: #cf8e8b;
#   color: #f1f1f1;
# }
# #T_8ede7_row42_col2 {
#   background-color: #dfb5b3;
#   color: #000000;
# }
# #T_8ede7_row43_col2 {
#   background-color: #c06a68;
#   color: #f1f1f1;
# }
# #T_8ede7_row46_col2 {
#   background-color: #efdad8;
#   color: #000000;
# }
# #T_8ede7_row47_col2 {
#   background-color: #dcacaa;
#   color: #000000;
# }
# #T_8ede7_row48_col2 {
#   background-color: #dcaeab;
#   color: #000000;
# }
# #T_8ede7_row50_col2, #T_8ede7_row58_col2 {
#   background-color: #cd8885;
#   color: #f1f1f1;
# }
# #T_8ede7_row51_col2 {
#   background-color: #faf0ef;
#   color: #000000;
# }
# #T_8ede7_row52_col2 {
#   background-color: #f9f5f5;
#   color: #000000;
# }
# #T_8ede7_row53_col2 {
#   background-color: #e1b9b6;
#   color: #000000;
# }
# #T_8ede7_row55_col2 {
#   background-color: #e6e6ec;
#   color: #000000;
# }
# #T_8ede7_row59_col2, #T_8ede7_row63_col2, #T_8ede7_row87_col2 {
#   background-color: #d4d8e2;
#   color: #000000;
# }
# #T_8ede7_row60_col2 {
#   background-color: #c06967;
#   color: #f1f1f1;
# }
# #T_8ede7_row61_col2 {
#   background-color: #c77b78;
#   color: #f1f1f1;
# }
# #T_8ede7_row62_col2 {
#   background-color: #d7dae4;
#   color: #000000;
# }
# #T_8ede7_row65_col2, #T_8ede7_row97_col2 {
#   background-color: #cad0dd;
#   color: #000000;
# }
# #T_8ede7_row67_col2, #T_8ede7_row78_col2 {
#   background-color: #d08f8d;
#   color: #f1f1f1;
# }
# #T_8ede7_row68_col2 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_8ede7_row69_col2 {
#   background-color: #b95b5a;
#   color: #f1f1f1;
# }
# #T_8ede7_row70_col2 {
#   background-color: #bbc5d7;
#   color: #000000;
# }
# #T_8ede7_row71_col2 {
#   background-color: #c97f7d;
#   color: #f1f1f1;
# }
# #T_8ede7_row72_col2 {
#   background-color: #eacfcd;
#   color: #000000;
# }
# #T_8ede7_row74_col2 {
#   background-color: #cb8481;
#   color: #f1f1f1;
# }
# #T_8ede7_row76_col2 {
#   background-color: #e5c2c0;
#   color: #000000;
# }
# #T_8ede7_row79_col2 {
#   background-color: #b44f4f;
#   color: #f1f1f1;
# }
# #T_8ede7_row82_col2 {
#   background-color: #d7a09d;
#   color: #000000;
# }
# #T_8ede7_row83_col2 {
#   background-color: #faf3f3;
#   color: #000000;
# }
# #T_8ede7_row84_col2 {
#   background-color: #ecd2d0;
#   color: #000000;
# }
# #T_8ede7_row85_col2 {
#   background-color: #ebeaee;
#   color: #000000;
# }
# #T_8ede7_row86_col2 {
#   background-color: #507ebc;
#   color: #f1f1f1;
# }
# #T_8ede7_row88_col2 {
#   background-color: #c3cbda;
#   color: #000000;
# }
# #T_8ede7_row89_col2 {
#   background-color: #ca817e;
#   color: #f1f1f1;
# }
# #T_8ede7_row90_col2 {
#   background-color: #cbd1de;
#   color: #000000;
# }
# #T_8ede7_row91_col2 {
#   background-color: #7393c0;
#   color: #f1f1f1;
# }
# #T_8ede7_row92_col2 {
#   background-color: #bc605e;
#   color: #f1f1f1;
# }
# #T_8ede7_row93_col2 {
#   background-color: #deb2b0;
#   color: #000000;
# }
# #T_8ede7_row95_col2 {
#   background-color: #faf3f2;
#   color: #000000;
# }
# #T_8ede7_row96_col2 {
#   background-color: #d0d5e0;
#   color: #000000;
# }
# #T_8ede7_row98_col2 {
#   background-color: #efd8d6;
#   color: #000000;
# }
# </style>
# <table id="T_8ede7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8ede7_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_8ede7_level0_col1" class="col_heading level0 col1" >TFIDF</th>
#       <th id="T_8ede7_level0_col2" class="col_heading level0 col2" >Sentiment</th>
#       <th id="T_8ede7_level0_col3" class="col_heading level0 col3" >Counts</th>
#       <th id="T_8ede7_level0_col4" class="col_heading level0 col4" >CoOccurre-FREQ</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8ede7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8ede7_row0_col0" class="data row0 col0" >br</td>
#       <td id="T_8ede7_row0_col1" class="data row0 col1" >0.187560</td>
#       <td id="T_8ede7_row0_col2" class="data row0 col2" >0.149914</td>
#       <td id="T_8ede7_row0_col3" class="data row0 col3" >25468</td>
#       <td id="T_8ede7_row0_col4" class="data row0 col4" >良い, v, 夢, 希望, 4</td>
#     </tr>
#     <tr>
#       <th id="T_8ede7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8ede7_row1_col0" class="data row1 col0" >ミミッキュ</td>
#       <td id="T_8ede7_row1_col1" class="data row1 col1" >0.046337</td>
#       <td id="T_8ede7_row1_col2" class="data row1 col2" >-0.172684</td>
#       <td id="T_8ede7_row1_col3" class="data row1 col3" >4598</td>
#       <td id="T_8ede7_row1_col4" class="data row1 col4" >良い, 強い, z, 1, 襷</td>
#     </tr>
#     <tr>
#       <th id="T_8ede7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8ede7_row2_col0" class="data row2 col0" >ミミ</td>
#       <td id="T_8ede7_row2_col1" class="data row2 col1" >0.039874</td>
#       <td id="T_8ede7_row2_col2" class="data row2 col2" >-0.243273</td>
#       <td id="T_8ede7_row2_col3" class="data row2 col3" >3605</td>
#       <td id="T_8ede7_row2_col4" class="data row2 col4" >良い, 強い, ポケモン, 2, 1</td>
#     </tr>
#     <tr>
#       <th id="T_8ede7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8ede7_row3_col0" class="data row3 col0" >良い</td>
#       <td id="T_8ede7_row3_col1" class="data row3 col1" >

# %% [markdown]
# ## 分析対象内

# %% [markdown]
# ## 母集団に対するTFIDF

# %% [markdown]
# ### 母集団TFIDFモデルをサルベージ

# %%
import pickle
from copy import deepcopy

with open(tfidf_model_file, "rb") as f:
    tfidf_model = pickle.load(f)

#対象（名詞・形容詞）を見せる用
tfidf_model_showing = deepcopy(tfidf_model)
tfidf_model_showing.ngram = (1,1)
tfidf_model_showing.tokenizer = tokenize

# %% [markdown]
# ### TFIDFを計算

# %%
#keywordに共起する回数の多いものを数える
def get_tfidf(keyword):
    #keywordを含む行を走査
    df_keyword = np.empty((0, df_main.shape[1]))
    for _, row in df_main.iterrows():
        if keyword in tokenize(row["disassembled_all"]):
            df_keyword = np.vstack([df_keyword, row.values])

    #pandas行列に
    df_keyword = pd.DataFrame(df_keyword, columns=df_main.columns)

    if df_keyword.shape[0] == 0:
        return pd.Series()

    #TFIDF計算
    tfidf_spycy = tfidf_model_showing.transform(df_keyword["disassembled_target"])
    tfidf_df = pd.DataFrame(tfidf_spycy.toarray(), columns=tfidf_model_showing.get_feature_names_out())
    tfidf_mean = tfidf_df.mean(axis=0)
    
    #単語名と結び付け
    tfidf_mean = tfidf_mean.sort_values(ascending=False)

    #ストップワードの削除
    for word in local_stopwords:
        tfidf_mean = tfidf_mean.drop(word)

    return tfidf_mean

get_tfidf("良い").head(5)
# Out:
# 良い            0.245514
# 夢             0.024792
# v             0.022091
# 良い ブイ-buoy    0.021629
# ブイ-buoy       0.021437
# dtype: float64

# %%
df_sentiment["CoOccurre-TFIDF"] = ""
for index, row in df_sentiment.iterrows():
    freq = get_tfidf(row["Token"])
    end = 6
    if len(freq) <= 1:
        end = 1
    elif len(freq) < 6:
        end = len(freq)

    if end != 1:
        cooc = ", ".join(list(freq.iloc[1:end].index))
        df_sentiment.at[index, "CoOccurre-TFIDF"] = cooc

pd.set_option('display.max_rows', 200)
df_sentiment.head(200).style.background_gradient(cmap="vlag_r", axis=0, subset="Sentiment")
# Out:
# C:\Users\brigh\AppData\Local\Temp\ipykernel_29624\2496609756.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# C:\Users\brigh\AppData\Local\Temp\ipykernel_29624\2496609756.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# C:\Users\brigh\AppData\Local\Temp\ipykernel_29624\2496609756.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# C:\Users\brigh\AppData\Local\Temp\ipykernel_29624\2496609756.py:13: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   return pd.Series()
# <style type="text/css">
# #T_47043_row0_col2, #T_47043_row38_col2 {
#   background-color: #f1eff2;
#   color: #000000;
# }
# #T_47043_row1_col2 {
#   background-color: #dfb4b2;
#   color: #000000;
# }
# #T_47043_row2_col2 {
#   background-color: #d7a29f;
#   color: #000000;
# }
# #T_47043_row3_col2 {
#   background-color: #f5f2f4;
#   color: #000000;
# }
# #T_47043_row4_col2 {
#   background-color: #ba5d5c;
#   color: #f1f1f1;
# }
# #T_47043_row5_col2 {
#   background-color: #839dc4;
#   color: #f1f1f1;
# }
# #T_47043_row6_col2 {
#   background-color: #3470bc;
#   color: #f1f1f1;
# }
# #T_47043_row7_col2, #T_47043_row77_col2 {
#   background-color: #efeef1;
#   color: #000000;
# }
# #T_47043_row8_col2 {
#   background-color: #c0c9d9;
#   color: #000000;
# }
# #T_47043_row9_col2, #T_47043_row56_col2, #T_47043_row73_col2 {
#   background-color: #eeedf0;
#   color: #000000;
# }
# #T_47043_row10_col2 {
#   background-color: #e2e3ea;
#   color: #000000;
# }
# #T_47043_row11_col2 {
#   background-color: #f0dbda;
#   color: #000000;
# }
# #T_47043_row12_col2 {
#   background-color: #2369bd;
#   color: #f1f1f1;
# }
# #T_47043_row13_col2 {
#   background-color: #d2d7e1;
#   color: #000000;
# }
# #T_47043_row14_col2, #T_47043_row15_col2, #T_47043_row66_col2, #T_47043_row94_col2 {
#   background-color: #dde0e7;
#   color: #000000;
# }
# #T_47043_row16_col2, #T_47043_row34_col2, #T_47043_row54_col2, #T_47043_row80_col2 {
#   background-color: #f4e3e2;
#   color: #000000;
# }
# #T_47043_row17_col2, #T_47043_row45_col2 {
#   background-color: #eed7d5;
#   color: #000000;
# }
# #T_47043_row18_col2, #T_47043_row49_col2 {
#   background-color: #c7cedc;
#   color: #000000;
# }
# #T_47043_row19_col2 {
#   background-color: #eacdcb;
#   color: #000000;
# }
# #T_47043_row20_col2 {
#   background-color: #d9a5a2;
#   color: #000000;
# }
# #T_47043_row21_col2, #T_47043_row57_col2 {
#   background-color: #d59c99;
#   color: #f1f1f1;
# }
# #T_47043_row22_col2 {
#   background-color: #c47371;
#   color: #f1f1f1;
# }
# #T_47043_row23_col2, #T_47043_row64_col2 {
#   background-color: #3f75bc;
#   color: #f1f1f1;
# }
# #T_47043_row24_col2, #T_47043_row44_col2, #T_47043_row75_col2 {
#   background-color: #e6c5c3;
#   color: #000000;
# }
# #T_47043_row25_col2 {
#   background-color: #bdc6d7;
#   color: #000000;
# }
# #T_47043_row26_col2, #T_47043_row32_col2 {
#   background-color: #c67875;
#   color: #f1f1f1;
# }
# #T_47043_row27_col2 {
#   background-color: #d39794;
#   color: #f1f1f1;
# }
# #T_47043_row28_col2 {
#   background-color: #e3bfbd;
#   color: #000000;
# }
# #T_47043_row29_col2 {
#   background-color: #adbbd1;
#   color: #000000;
# }
# #T_47043_row30_col2 {
#   background-color: #faf2f1;
#   color: #000000;
# }
# #T_47043_row31_col2 {
#   background-color: #e8cac8;
#   color: #000000;
# }
# #T_47043_row33_col2 {
#   background-color: #9fb0cc;
#   color: #000000;
# }
# #T_47043_row35_col2 {
#   background-color: #abb9d0;
#   color: #000000;
# }
# #T_47043_row36_col2, #T_47043_row81_col2 {
#   background-color: #dcdee6;
#   color: #000000;
# }
# #T_47043_row37_col2 {
#   background-color: #d29593;
#   color: #f1f1f1;
# }
# #T_47043_row39_col2 {
#   background-color: #d8a3a0;
#   color: #000000;
# }
# #T_47043_row40_col2 {
#   background-color: #f8f4f5;
#   color: #000000;
# }
# #T_47043_row41_col2, #T_47043_row99_col2 {
#   background-color: #cf8e8b;
#   color: #f1f1f1;
# }
# #T_47043_row42_col2 {
#   background-color: #dfb5b3;
#   color: #000000;
# }
# #T_47043_row43_col2 {
#   background-color: #c06a68;
#   color: #f1f1f1;
# }
# #T_47043_row46_col2 {
#   background-color: #efdad8;
#   color: #000000;
# }
# #T_47043_row47_col2 {
#   background-color: #dcacaa;
#   color: #000000;
# }
# #T_47043_row48_col2 {
#   background-color: #dcaeab;
#   color: #000000;
# }
# #T_47043_row50_col2, #T_47043_row58_col2 {
#   background-color: #cd8885;
#   color: #f1f1f1;
# }
# #T_47043_row51_col2 {
#   background-color: #faf0ef;
#   color: #000000;
# }
# #T_47043_row52_col2 {
#   background-color: #f9f5f5;
#   color: #000000;
# }
# #T_47043_row53_col2 {
#   background-color: #e1b9b6;
#   color: #000000;
# }
# #T_47043_row55_col2 {
#   background-color: #e6e6ec;
#   color: #000000;
# }
# #T_47043_row59_col2, #T_47043_row63_col2, #T_47043_row87_col2 {
#   background-color: #d4d8e2;
#   color: #000000;
# }
# #T_47043_row60_col2 {
#   background-color: #c06967;
#   color: #f1f1f1;
# }
# #T_47043_row61_col2 {
#   background-color: #c77b78;
#   color: #f1f1f1;
# }
# #T_47043_row62_col2 {
#   background-color: #d7dae4;
#   color: #000000;
# }
# #T_47043_row65_col2, #T_47043_row97_col2 {
#   background-color: #cad0dd;
#   color: #000000;
# }
# #T_47043_row67_col2, #T_47043_row78_col2, #T_47043_row100_col2 {
#   background-color: #d08f8d;
#   color: #f1f1f1;
# }
# #T_47043_row68_col2 {
#   background-color: #a9373b;
#   color: #f1f1f1;
# }
# #T_47043_row69_col2 {
#   background-color: #b95b5a;
#   color: #f1f1f1;
# }
# #T_47043_row70_col2 {
#   background-color: #bbc5d7;
#   color: #000000;
# }
# #T_47043_row71_col2 {
#   background-color: #c97f7d;
#   color: #f1f1f1;
# }
# #T_47043_row72_col2 {
#   background-color: #eacfcd;
#   color: #000000;
# }
# #T_47043_row74_col2 {
#   background-color: #cb8481;
#   color: #f1f1f1;
# }
# #T_47043_row76_col2 {
#   background-color: #e5c2c0;
#   color: #000000;
# }
# #T_47043_row79_col2 {
#   background-color: #b44f4f;
#   color: #f1f1f1;
# }
# #T_47043_row82_col2 {
#   background-color: #d7a09d;
#   color: #000000;
# }
# #T_47043_row83_col2 {
#   background-color: #faf3f3;
#   color: #000000;
# }
# #T_47043_row84_col2 {
#   background-color: #ecd2d0;
#   color: #000000;
# }
# #T_47043_row85_col2 {
#   background-color: #ebeaee;
#   color: #000000;
# }
# #T_47043_row86_col2 {
#   background-color: #507ebc;
#   color: #f1f1f1;
# }
# #T_47043_row88_col2 {
#   background-color: #c3cbda;
#   color: #000000;
# }
# #T_47043_row89_col2 {
#   background-color: #ca817e;
#   color: #f1f1f1;
# }
# #T_47043_row90_col2 {
#   background-color: #cbd1de;
#   color: #000000;
# }
# #T_47043_row91_col2 {
#   background-color: #7393c0;
#   color: #f1f1f1;
# }
# #T_47043_row92_col2 {
#   background-color: #bc605e;
#   color: #f1f1f1;
# }
# #T_47043_row93_col2 {
#   background-color: #deb2b0;
#   color: #000000;
# }
# #T_47043_row95_col2 {
#   background-color: #faf3f2;
#   color: #000000;
# }
# #T_47043_row96_col2 {
#   background-color: #d0d5e0;
#   color: #000000;
# }
# #T_47043_row98_col2 {
#   background-color: #efd8d6;
#   color: #000000;
# }
# </style>
# <table id="T_47043">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47043_level0_col0" class="col_heading level0 col0" >Token</th>
#       <th id="T_47043_level0_col1" class="col_heading level0 col1" >TFIDF</th>
#       <th id="T_47043_level0_col2" class="col_heading level0 col2" >Sentiment</th>
#       <th id="T_47043_level0_col3" class="col_heading level0 col3" >Counts</th>
#       <th id="T_47043_level0_col4" class="col_heading level0 col4" >CoOccurre-FREQ</th>
#       <th id="T_47043_level0_col5" class="col_heading level0 col5" >CoOccurre-TFIDF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47043_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47043_row0_col0" class="data row0 col0" >br</td>
#       <td id="T_47043_row0_col1" class="data row0 col1" >0.187560</td>
#       <td id="T_47043_row0_col2" class="data row0 col2" >0.149914</td>
#       <td id="T_47043_row0_col3" class="data row0 col3" >25468</td>
#       <td id="T_47043_row0_col4" class="data row0 col4" >良い, v, 夢, 希望, 4</td>
#       <td id="T_47043_row0_col5" class="data row0 col5" >希望, 無い, 登録, 夢, v</td>
#     </tr>
#     <tr>
#       <th id="T_47043_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47043_row1_col0" class="data row1 col0" >ミミッキュ</td>
#       <td id="T_47043_row1_col1" class="data row1 col1" >0.046337</td>
#       <td id="T_47043_row1_col2" class="data row1 col2" >-0.172684</td>
#       <td id="T_47043_row1_col3" class="data row1 col3" >4598</td>
#       <td id="T_47043_row1_col4" class="data row1 col4" >良い, 強い, z, 1, 襷</td>
#       <td id="T_47043_row1_col5" class="data row1 col5" >良い, 強い, z, 襷, トリル-trill</td>
#     </tr>
#     <tr>
#       <th id="T_47043_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47043_row2_col0" class="data row2 col0" >ミミ</td>
#       <td id="T_47043_row2_col1" class="data row2 col1" >0.039874</td>
#       <td id="T_47043_row2_col2" class="data row2 col2" >-0.243273</td>
#       <td id="T_47043_row2_col3" class="data row2 col3" >3605</td>
#       <td id="T_47043
